# %%
#Q.1 
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.amazon.in.")

# %%
user_input=input("What u like to Search:-")
# Out:
# What u like to Search:-Watch

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search.send_keys(user_input)

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
#Q.2
#fetching url to open each watch
prod_url=[]
start=0
end=2
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        prod_url.append(i.get_attribute('href'))
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[69]/div/div/span/a[3]')

# %%
len(prod_url)
# Out:
# 142

# %%
prod_url
# Out:
# ['https://www.amazon.in./sspa/click?ie=UTF8&spc=MToyOTc0NTYzNTExMjA4MTY3OjE3MTg1MzMwNTE6c3BfYXRmOjMwMDIwMjg5NDkzNDEzMjo6MDo6&url=%2FFire-Boltt-Bluetooth-Calling-Assistance-Resolution%2Fdp%2FB0BF57RN3K%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2H8QY4ZASZATB%26dib%3DeyJ2IjoiMSJ9.vKfqLC6smR8BJ9MSEBt3Gc9c95yJKPVevYnRFhd2dbwD5MaTUwBnvvMZHsu9gU-Qao2DkkyHiznXowYcZMfOYCIXYVkgh82Im2FC9K4LpJJIBa4zi0m4a6I5LzWxPRMQsCu1Dl7Ep2QbgQwlACb2tK91G5-fvsCS9k3yVv_ubrjbRHrLSNjxnZfP6vCruz4LX1FD2W0zaceBInjLoJBgQpkmBR8iJ-xPgswiFXhhOvfF2dSkHuecsAxt5VIPs5np_0godOuXXSsJTnfmJZ1woip0UN6xU1M-eZhp_dQDoso.rqv9R7UiLPRZZqVhJX7MjfI8IAx7umoAN6QczYx17kc%26dib_tag%3Dse%26keywords%3DWatch%26qid%3D1718533051%26sprefix%3Dwatch%252Caps%252C3077%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
brand_name=[]
product_name=[]
price=[]
return_exchange=[]
exp_del=[]
avail=[]
prod_urls=[]

# %%
for i in prod_url:# iterating each and every url to fetch full job details
    driver.get(i) #taking each url one by one as an input
    time.sleep(5)
    try: #brand name
        brnd=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[11]/div/div[3]/div/div/div[1]/div[1]/p/span')
        brand_name.append(brnd.text)
    except NoSuchElementException :
        brand_name.append('-')
        
    try: # product name
        prd=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[1]/div/h1/span')
        product_name.append(prd.text)
    except NoSuchElementException :
        product_name.append('-')
        
    try: #price
        prc=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[14]/div/div/div[4]/div[1]/span[3]/span[2]/span[2]')
        price.append(prc.text)
    except NoSuchElementException :
        price.append('-')
        
    try: #return and exchange
        re=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[4]/div/div[1]/div/div[1]/div/div/div[1]/div/div[1]/h5/div[2]/span/span/span')
        return_exchange.append(re.text)
    except NoSuchElementException :
        return_exchange.append('-')
        
    try: #expected delivery
        ed=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[4]/div/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/form/div/div/div[3]/div[10]/div[1]/div/div/div/span/span')
        exp_del.append(ed.text)
    except NoSuchElementException :
        exp_del.append('-')
        
    try: #availability
        av=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[4]/div/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/form/div/div/div[5]/div/div[1]/span')
        avail.append(av.text)
    except NoSuchElementException :
        avail.append('-')
        
    try: #Product url
        pu=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[3]/div/div/div/div/span/div/div/div[1]/div/span/a')
        prod_urls.append(pu.text)
    except NoSuchElementException :
        prod_urls.append('-')

# %%
print(len(brand_name),len(product_name),len(price),len(return_exchange),len(exp_del),len(avail),len(prod_url))
# Out:
# 142 142 142 142 142 142 142

# %%
df=pd.DataFrame({'Brand Name':brand_name,'Product Name':product_name,'Price':price,'Expected Delivery':exp_del,'Availability':avail,'Product URL':prod_url})
df
# Out:
#      Brand Name                                       Product Name  Price  \
# 0    Fire-Boltt  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...  1,099
# 1    Fire-Boltt  Fire-Boltt Phoenix Pro 1.39" Bluetooth Calling...  1,499
# 2         Noise  NoiseFit Halo 1.43" AMOLED Display, Bluetooth ...  2,499
# 3    Fire-Boltt  Fire-Boltt India's No 1 Smartwatch Brand Talk ...    999
# 4    Fire-Boltt  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...  1,099
# ..          ...                                                ...    ...
# 137           -                                                  -      -
# 138           -                                                  -      -
# 139           -                                                  -      -
# 140           -                                                  -      -
# 141           -                                                  -      -
#
#       Expected Delivery Availability  \
# 0    Wednesday, 19 June     In stock
# ...

# %%
#Q.3
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://images.google.com")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search.send_keys("Fruits")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")
    img_url=[]
    img_url=driver.find_elements(By.XPATH,'//img[@class="YQ4gaf"]')
    
for i in range(len(img_url)):
    if i>10:
        breakBy.XPATH,
        print("Downloading {0} of {1} images" .format(i,10))
        response=requests.get(img[i])
        file=open(r"C:\Users\Admin\Desktop"+str(i)+".jpg", "wb")
        file.write(response.content)

# %%
len(img_url)
# Out:
# 100

# %%
for i in img_url[0:10]:
    print(i.get_attribute('src'))
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
#Q.4
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()
driver.get("https://www.flipkart.com")

# %%
desg=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input")
desg.send_keys("smartphone")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/button")
search.click()

# %%
brand_name=[]
sphone_name=[]
color=[]
ram=[]
rom=[]
pri_cam=[]
sec_cam=[]
disp_size=[]
battery_cap=[]
price=[]
prod_url=[]

# %%
#fetching url to open each smartphone
url_list=[]
url=driver.find_elements(By.XPATH,'//a[@class="CGtC98"]')
for i in url:
    url_list.append(i.get_attribute('href'))

# %%
len(url_list)
# Out:
# 24

# %%
url_list
# Out:
# ['https://www.flipkart.com/motorola-g34-5g-ocean-green-128-gb/p/itm6b1a33b9d9191?pid=MOBGUFK4TZ2CJYHJ&lid=LSTMOBGUFK4TZ2CJYHJPBUF6M&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=86a08201-9c7b-494f-91b5-cf8f86ec275a.MOBGUFK4TZ2CJYHJ.SEARCH&ppt=sp&ppn=sp&ssid=nlcvpfsytc0000001718531416251&qH=1036ba3c4ed2c021',
#  'https://www.flipkart.com/motorola-g34-5g-charcoal-black-128-gb/p/itmcf3922f5c94b2?pid=MOBGUFK4QPQMAA2S&lid=LSTMOBGUFK4QPQMAA2SCAYBBS&marketplace=FLIPKART&q=smartphone&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=86a08201-9c7b-494f-91b5-cf8f86ec275a.MOBGUFK4QPQMAA2S.SEARCH&ppt=hp&ppn=homepage&ssid=nlcvpfsytc0000001718531416251&qH=1036ba3c4ed2c021',
# ...

# %%
for i in url_list:# iterating each and every url to fetch full smartphone details
    driver.get(i) 
    time.sleep(5)
    try: #brand name with phone name
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span')
        brand_name.append(brnd.text)
    except NoSuchElementException :
        brand_name.append('-')
        
    try: #color
        cl=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]')
        color.append(cl.text)
    except NoSuchElementException :
        color.append('-')
        
    try: #ram_rom
        re=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[1]')
        ram.append(re.text)
    except NoSuchElementException :
        ram.append('-')
        
    try: #primary camera
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[3]')
        pri_cam.append(brnd.text)
    except NoSuchElementException :
        pri_cam.append('-')
        
    try: # secondary camera
        sp=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[5]/table/tbody/tr[5]/td[2]/ul/li')
        sec_cam.append(sp.text)
    except NoSuchElementException :
        sec_cam.append('-')
        
    try: #display size
        cl=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[2]')
        disp_size.append(cl.text)
    except NoSuchElementException :
        disp_size.append('-')
        
    try: #battery capacity 
        re=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]')
        battery_cap.append(re.text)
    except NoSuchElementException :
        battery_cap.append('-')
        
    try: #price 
        re=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]')
        price.append(re.text)
    except NoSuchElementException :
        price.append('-')

# %%
print(len(brand_name),len(color),len(ram),len(pri_cam),len(sec_cam),len(disp_size),len(battery_cap),len(price))
# Out:
# 24 24 24 24 24 24 24 24

# %%
df=pd.DataFrame({'Phone Name with Brand':brand_name,'Price':price,'Color':color,'Ram|Rom':ram,'Primary|Secondary Camera':pri_cam,'Display Size':disp_size,'Battery Capacity':battery_cap})
df
# Out:
#                                 Phone Name with Brand    Price  \
# 0   Motorola G34 5G (Ocean Green, 128 GB)  (8 GB RAM)  ₹11,999
# 1   Motorola G34 5G (Charcoal Black, 128 GB)  (8 G...  ₹11,999
# 2          POCO C65 (Pastel Blue, 128 GB)  (4 GB RAM)   ₹6,799
# 3      Motorola G34 5G (Ice Blue, 128 GB)  (8 GB RAM)  ₹11,999
# 4          POCO C65 (Matte Black, 128 GB)  (4 GB RAM)   ₹6,799
# 5    POCO M6 Pro 5G (Power Black, 128 GB)  (6 GB RAM)   ₹9,999
# 6       Motorola g04s (Satin Blue, 64 GB)  (4 GB RAM)   ₹6,999
# 7   SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB) ...   ₹9,490
# 8    Motorola g04s (Concord Black, 64 GB)  (4 GB RAM)   ₹6,999
# 9      REDMI 13C (Stardust Black, 128 GB)  (4 GB RAM)   ₹7,699
# 10  SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)  (6 ...   ₹9,490
# 11        POCO C65 (Pastel Green, 128 GB)  (4 GB RAM)   ₹6,799
# 12    vivo T3x 5G (Crimson Bliss, 128 GB)  (6 GB RAM)  ₹14,999
# 13  vivo T3x 5G (Celestial Green, 128 GB)  (8 GB RAM)  ₹16,499
# ...

# %%
df.to_csv("smartphones.csv")

# %%
#Q.6
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome()
driver.get("https://www.digit.in")

# %%
desg=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div/div/div[2]/form/input[1]")
desg.send_keys("gaming laptop")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div/div/div[2]/form/button/i")
search.click()

# %%
#fetching url to open each laptop
url_list=[]
url=driver.find_elements(By.XPATH,'//h3[@class=" text-clamp text-clamp-2"]/a')
for i in url:
    url_list.append(i.get_attribute('href'))

# %%
len(url_list)
# Out:
# 12

# %%
url_list
# Out:
# ['https://www.digit.in/laptops/hp-omen-transcend-gaming-laptop-14-fb0089tx-price.html',
#  'https://www.digit.in/laptops/dell-alienware-m18-r1-gaming-laptop-price.html',
#  'https://www.digit.in/laptops/hp-omen-gaming-laptop-16-xf0059ax-price.html',
#  'https://www.digit.in/laptops/hp-omen-gaming-laptop-16-wf1025tx-price.html',
#  'https://www.digit.in/laptops/hp-omen-gaming-laptop-16-xd0007ax.html',
#  'https://www.digit.in/laptops/dell-g15-5520-gaming-laptop.html',
#  'https://www.digit.in/laptops/acer-predator-helios-neo-16-gaming-laptop.html',
#  'https://www.digit.in/laptops/dell-alienware-m16-r1-gaming-laptop-price-350853.html',
#  'https://www.digit.in/laptops/dell-alienware-x14-r2-gaming-laptop-price-350232.html',
#  'https://www.digit.in/laptops/hp-victus-gaming-laptop-16-r0075tx-price-349620.html',
#  'https://www.digit.in/laptops/alienware-x14-gaming-laptop-price-318804.html',
#  'https://www.digit.in/laptops/asus-tuf-gaming-laptop-fx506li-hn270t-price-256693.html']

# %%
lap_name=[]
price=[]
op_sys=[]
disp_size=[]
pro_name=[]
storage_cap=[]

# %%
for i in url_list:# iterating each and every url to fetch full laptop details
    driver.get(i) 
    time.sleep(5)
    try: #laptop name 
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[1]/h1')
        lap_name.append(brnd.text)
    except NoSuchElementException :
        lap_name.append('-')
        
    try: # price
        sp=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[9]/div[1]/div/div[2]/div[3]/div/div[1]')
        price.append(sp.text)
    except NoSuchElementException :
        price.append('-')
        
    try: #operating system
        cl=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div[1]/div/ul/li[1]/div/p[2]/strong')
        op_sys.append(cl.text)
    except NoSuchElementException :
        op_sys.append('-')
        
    try: #display size
        re=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div[1]/div/ul/li[2]/div/p[2]/strong')
        disp_size.append(re.text)
    except NoSuchElementException :
        disp_size.append('-')
        
    try: #processor name
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div[1]/div/ul/li[3]/div/p[2]/strong')
        pro_name.append(brnd.text)
    except NoSuchElementException :
        pro_name.append('-')
        
    try: # storage capacity
        sp=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div[1]/div/ul/li[4]/div/p[2]/strong')
        storage_cap.append(sp.text)
    except NoSuchElementException :
        storage_cap.append('-')

# %%
print(len(lap_name),len(price),len(op_sys),len(disp_size),len(pro_name),len(storage_cap))
# Out:
# 12 12 12 12 12 12

# %%
df=pd.DataFrame({'Laptop Name':lap_name,'Price':price,'Operating System':op_sys,'Display size':disp_size,'Processor Name':pro_name,'Storage Capacity':storage_cap})
df
# Out:
#                                     Laptop Name         Price  \
# 0   HP OMEN Transcend Gaming Laptop 14-Fb0089TX       Rs. 379
# 1           Dell Alienware M18 R1 Gaming Laptop   Rs. 409,990
# 2           HP Omen Gaming Laptop (16-Xf0059AX)  out of stock
# 3           HP Omen Gaming Laptop (16-Wf1025TX)       Rs. 299
# 4             HP OMEN Gaming Laptop 16 XD0007ax       Rs. 299
# 5                   Dell G15 5520 Gaming Laptop    Rs. 84,999
# 6     Acer Predator Helios Neo 16 Gaming Laptop   Rs. 108,790
# 7           Dell Alienware M16 R1 Gaming Laptop       Rs. 225
# 8           Dell Alienware X14 R2 Gaming Laptop   Rs. 157,990
# 9                                             -             -
# 10                                            -             -
# 11                                            -             -
#
#    Operating System                   Display size  \
# 0   Windows 11 Home                             14
# 1   Windows 11 Home                             18
# ...

# %%
#Q.7
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome()
driver.get("https://www.forbes.com/real-time-billionaires/#69d3b1293d78")

# %%
rank=[]
name=[]
nw=[]
age=[]
czn=[]
src=[]
ind=[]

# %%
#fetching url to open each billionaires
url_list=[]
url=driver.find_elements(By.XPATH,'//div[@class="ng-scope"]/h3/a')
for i in url:
    url_list.append(i.get_attribute('href'))

# %%
len(url_list)
# Out:
# 25

# %%
url_list
# Out:
# ['https://www.forbes.com/profile/elon-musk/?list=rtb/',
#  'https://www.forbes.com/profile/jeff-bezos/?list=rtb/',
#  'https://www.forbes.com/profile/bernard-arnault/?list=rtb/',
#  'https://www.forbes.com/profile/larry-ellison/?list=rtb/',
#  'https://www.forbes.com/profile/mark-zuckerberg/?list=rtb/',
#  'https://www.forbes.com/profile/larry-page/?list=rtb/',
#  'https://www.forbes.com/profile/sergey-brin/?list=rtb/',
#  'https://www.forbes.com/profile/warren-buffett/?list=rtb/',
#  'https://www.forbes.com/profile/bill-gates/?list=rtb/',
#  'https://www.forbes.com/profile/steve-ballmer/?list=rtb/',
#  'https://www.forbes.com/profile/jensen-huang/?list=rtb/',
#  'https://www.forbes.com/profile/mukesh-ambani/?list=rtb/',
#  'https://www.forbes.com/profile/amancio-ortega/?list=rtb/',
#  'https://www.forbes.com/profile/michael-dell/?list=rtb/',
#  'https://www.forbes.com/profile/michael-bloomberg/?list=rtb/',
#  'https://www.forbes.com/profile/francoise-bettencourt-meyers/?list=rtb/',
# ...

# %%
for i in url_list:# iterating each and every url to fetch billionaire details
    driver.get(i) 
    time.sleep(5)
    try: #rank 
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[1]/span[1]')
        rank.append(brnd.text)
    except NoSuchElementException :
        rank.append('-')
        
    try: # name
        sp=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[2]/div/div/div/div[1]/h1')
        name.append(sp.text)
    except NoSuchElementException :
        name.append('-')
        
    try: #networth
        cl=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div[2]/div/div/div/div[1]/div[3]/div/div[1]/div')
        nw.append(cl.text)
    except NoSuchElementException :
        nw.append('-')
        
    try: #age
        re=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div[1]/div[4]/dl/dl[1]/dd/span')
        age.append(re.text)
    except NoSuchElementException :
        age.append('-')
        
    try: #citizenship
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div[1]/div[4]/dl/dl[5]/dd/span')
        czn.append(brnd.text)
    except NoSuchElementException :
        czn.append('-')
        
    try: # source
        sp=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div[1]/div[4]/dl/dl[2]/dd/span')
        src.append(sp.text)
    except NoSuchElementException :
        src.append('-')

# %%
print(len(rank),len(name),len(nw),len(age),len(czn),len(src))
# Out:
# 25 25 25 25 25 25

# %%
df=pd.DataFrame({'Rank':rank,'Name':name,'Age':age,'Networth':nw,'Citizenship':czn,'Source':src})
df
# Out:
#    Rank                                   Name Age                Networth  \
# 0    #1                              Elon Musk  52                 $214.1B
# 1    #2                             Jeff Bezos  60                 $200.4B
# 2    #3               Bernard Arnault & family  75  $192.5B\n$777M (0.40%)
# 3    #4                          Larry Ellison  79                 $176.1B
# 4    #5                        Mark Zuckerberg  40                 $175.1B
# 5    #6                             Larry Page  51                 $144.8B
# 6    #7                            Sergey Brin  50                 $138.7B
# 7    #8                         Warren Buffett  93                 $134.3B
# 8    #9                             Bill Gates  68   $133.6B\n$61M (0.05%)
# 9   #10                          Steve Ballmer  68                 $130.6B
# 10  #11                           Jensen Huang  61                 $118.7B
# ...

# %%
#Q.9
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome()
driver.get("https://www.hostelworld.com/st/hostels/europe/england/london/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[3]/header/div[2]/div[2]/div/div[1]/div/div[2]/div/div[5]/button[1]/div")
search.click()

# %%
#fetching url to open each hostels
url_list=[]
url=driver.find_elements(By.XPATH,'//div[@class="property-card"]/a[1]/a[1]')
for i in url:
    url_list.append(i.get_attribute('href'))

# %%
len(url_list)
# Out:
# 32

# %%
url_list
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/Palmers%20Lodge%20-%20Swiss%20Cottage/London/14348?from=2024-06-16&to=2024-06-19&guests=2',
#  "https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Village/London/502?from=2024-06-16&to=2024-06-19&guests=2",
#  "https://www.hostelworld.com/pwa/hosteldetails.php/Wombat's%20City%20Hostel%20London/London/88047?from=2024-06-16&to=2024-06-19&guests=2",
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Palmers%20Lodge%20-%20Swiss%20Cottage/London/14348?from=2024-06-16&to=2024-06-19&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany%20Hostel%20London/London/303427?from=2024-06-16&to=2024-06-19&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Onefam%20Waterloo/London/39493?from=2024-06-16&to=2024-06-19&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/NX%20London%20Hostel/London/15204?from=2024-06-16&to=2024-06-19&guests=2',
# ...

# %%
host_nm=[]
dist=[]
rat=[]
rev_tot=[]
ov_rev=[]
pri_price=[]
dorms_price=[]
faci=[]
prop_desc=[]

# %%
for i in url_list:# iterating each and every url to fetch full hostel details
    driver.get(i) 
    time.sleep(5)
    try: #hostel name 
        brnd=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div[3]/div[1]/div[1]/h1')
        host_nm.append(brnd.text)
    except NoSuchElementException :
        host_nm.append('-')
        
    try: # distance from city
        sp=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div[3]/div[1]/div[1]/ul/li[4]')
        dist.append(sp.text)
    except NoSuchElementException :
        dist.append('-')
        
    try: #ratings
        cl=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div[3]/div[1]/div[2]/div/div[1]/span[1]')
        rat.append(cl.text)
    except NoSuchElementException :
        rat.append('-')
        
    try: #overall reviews
        brnd=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[7]/div/div/div[1]')
        ov_rev.append(brnd.text)
    except NoSuchElementException :
        ov_rev.append('-')
        
    try: # private price
        sp=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/p[2]')
        pri_price.append(sp.text)
    except NoSuchElementException :
        pri_price.append('-')
        
    try: #dorms price
        re=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[3]/div/section/div/div[2]/div[2]/div/div[2]/div[1]/div[2]/div[1]/div[1]/div[3]/div')
        dorms_price.append(re.text)
    except NoSuchElementException :
        dorms_price.append('-')
        
    try: #facilities
        brnd=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[6]/div/div[3]/div')
        faci.append(brnd.text)
    except NoSuchElementException :
        faci.append('-')
        
    try: # property description
        sp=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[1]')
        prop_desc.append(sp.text)
    except NoSuchElementException :
        prop_desc.append('-')

# %%
print(len(host_nm),len(dist),len(rat),len(ov_rev),len(pri_price),len(dorms_price),len(faci),len(prop_desc))
# Out:
# 32 32 32 32 32 32 32 32

# %%
df=pd.DataFrame({'Hostel Name':host_nm,'Distance':dist,'Ratings':rat,'Overall Reviews':ov_rev,'Private price':pri_price,'Dorms price':dorms_price,'Facilities':faci,'Propert Description':prop_desc})
df
# Out:
#                                 Hostel Name                  Distance Ratings  \
# 0             Palmers Lodge - Swiss Cottage    6.5km from city centre     8.7
# 1                  St Christopher's Village   1.78km from city centre     7.6
# 2               Wombat's City Hostel London   3.57km from city centre     9.3
# 3             Palmers Lodge - Swiss Cottage    6.5km from city centre     8.7
# 4                      Urbany Hostel London   5.38km from city centre     9.6
# 5                           Onefam Waterloo   0.65km from city centre     9.5
# 6                          NX London Hostel   6.14km from city centre     8.8
# 7                                  Clink261   3.24km from city centre     8.2
# 8                       Onefam Notting Hill   5.46km from city centre     9.7
# 9                  St Christopher's Village   1.78km from city centre     7.6
# 10                         Generator London   2.97km from city centre     7.2
# ...

# %%
#Q.8
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=U2zbgPUBsqg&t=31s")#link of motivational speaker Shiv khera

# %%
comments=[]
time=[]
cmnt_up=[]

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

comment_tags=driver.find_elements(By.XPATH,'//span[@class="yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap"]')
for i in comment_tags:
        comm=i.text
        comments.append(comm)
    
time_tags=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-view-model"]/a[1]')
for i in time_tags:
        tm=i.text
        time.append(tm) 
comup_tags=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-engagement-bar"]')
for i in comup_tags:
        comm=i.text
        cmnt_up.append(comm)

# %%
print(len(comments),len(time),len(cmnt_up))
# Out:
# 188 180 180

# %%
df=pd.DataFrame({'Comments':comments})
df
# Out:
#                                               Comments
# 0    What is the secret of success? Do successful p...
# 1    श्री शिव खेड़ा ऐसे मार्गदर्शक हैं जो वस्तुतः स...
# 2    आप के विचार बहुत ही प्रेरणा दायक है सर । धन्यव...
# 3    जीत आपकी किताब  सफलता का प्रमाण हैं   धन्यवाद ...
# 4                                               Great
# ..                                                 ...
# 183
# 184
# 185
# 186
# 187
#
# [188 rows x 1 columns]

# %%
df1=pd.DataFrame({'Time':time,'Comment Upvote':cmnt_up})
df
# Out:
#              Time Comment Upvote
# 0     3 years ago             26
# 1      1 year ago              2
# 2     4 years ago              3
# 3    8 months ago              1
# 4      1 year ago              1
# ..            ...            ...
# 175   4 years ago              7
# 176   4 years ago              1
# 177   4 years ago
# 178   4 years ago              1
# 179    1 year ago              1
#
# [180 rows x 2 columns]

# %%
#Q.5
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()
driver.get("https://www.google.com/maps/")

# %%
user_input=input("What u like to Search:-")
# Out:
# What u like to Search:-pune

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input')
search.send_keys(user_input)

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button")
search.click()

# %%
import re
try:
    url=driver.current_url
    print("URL Extracted: ",url)
    lat_long=re.findall(r'@(.*)data',url)
except:
    print("invalid")
# Out:
# URL Extracted:  https://www.google.com/maps/@18.8181772,76.7698374,7z?entry=ttu

# %%
lat=url.replace("//","").split("2F%40")[0].split("%2C")[1]

lon=url.replace("//","").split("%2C")[2]

# %%
print(user_input,lat,lon)
# Out:
# Pune 18.5248706 73.6981494
