# %%
#Q.3
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART')

# %%
rating=[]
review_sum=[]
full_rew=[]

# %%
#Scraping rating from given page
rat_tags=driver.find_elements(By.XPATH,'//div[@class="XQDdHH Ga3i8K"]')
for i in rat_tags:
    rats=i.text
    rating.append(rats)
    
#Scraping Review summary from given page
sum_tags=driver.find_elements(By.XPATH,'//p[@class="z9E0IG"]')
for i in sum_tags:
    summary=i.text
    review_sum.append(summary)    
    
#Scraping full summary from given page
rev_tags=driver.find_elements(By.XPATH,'//div[@class="ZmyHeo"]')
for i in rev_tags:
    rev_sum=i.text
    full_rew.append(rev_sum)

# %%
rats=[]
revs=[]
revf=[]

# %%
print(len(rating),len(review_sum),len(full_rew))
# Out:
# 10 10 10

# %%
start=0
end=10
for page in range(start,end):
    ratings=driver.find_elements(By.XPATH,'//div[@class="XQDdHH Ga3i8K"]')
    for i in ratings:
        rats.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]')#to scrape data from next pages as well
    next_button.click()
    time.sleep(3)

# %%
print(len(rats))
# Out:
# 100

# %%
start=0
end=10
for page in range(start,end):
    revis=driver.find_elements(By.XPATH,'//p[@class="z9E0IG"]')
    for i in revis:
        revs.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]')#to scrape data from next pages as well
    next_button.click()
    time.sleep(3)

# %%
start=0
end=10
for page in range(start,end):
    revif=driver.find_elements(By.XPATH,'//div[@class="ZmyHeo"]')
    for i in revif:
        revf.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]')#to scrape data from next pages as well
    next_button.click()
    time.sleep(3)

# %%
print(len(revs),len(revf))
# Out:
# 100 100

# %%
df=pd.DataFrame({'Rating':rats,'Review_summary':revs,'Full_summary':revf})
df
# Out:
#    Rating       Review_summary  \
# 0       5     Perfect product!
# 1       5  Best in the market!
# 2       5       Classy product
# 3       5    Terrific purchase
# 4       5    Worth every penny
# ..    ...                  ...
# 95      4     Perfect product!
# 96      5             Terrific
# 97      5            Brilliant
# 98      5            Fabulous!
# 99      5       Simply awesome
#
#                                          Full_summary
# 0                                        Photos super
# 1                                         Good Camera
# 2   Camera is awesome\nBest battery backup\nA perf...
# 3                                   Value for money 😍
# 4   Feeling awesome after getting the delivery of ...
# ..                                                ...
# 95                                        Nice 👌👌👌👌👌👌
# 96                                           Must buy
# 97                        Good looking awesome mobile
# ...

# %%
#Q.4
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"Pke_EE")
designation.send_keys('Sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
brand=[]
prod_des=[]
price=[]

# %%
#Scraping Brand from given page
brand_tags=driver.find_elements(By.XPATH,'//div[@class="syl9yP"]')
for i in brand_tags:
    brd=i.text
    brand.append(brd)
    
#Scraping Product Description from given page
prod_tags=driver.find_elements(By.XPATH,'//a[@class="WKTcLC"]')
for i in prod_tags:
    prds=i.text
    prod_des.append(prds)    
    
#Scraping price from given page
prc_tags=driver.find_elements(By.XPATH,'//div[@class="Nx9bqj"]')
for i in prc_tags:
    prc=i.text
    price.append(prc)

# %%
brands=[]
product_des=[]
prices=[]

# %%
start=0
end=3
for page in range(start,end):
    brds=driver.find_elements(By.XPATH,'//div[@class="syl9yP"]')
    for i in brds:
        brands.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)

# %%
start=0
end=3
for page in range(start,end):
    prd=driver.find_elements(By.XPATH,'//a[@class="WKTcLC"]')
    for i in prd:
        product_des.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)

# %%
start=0
end=3
for page in range(start,end):
    prcs=driver.find_elements(By.XPATH,'//div[@class="Nx9bqj"]')
    for i in prcs:
        prices.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brands),len(product_des),len(prices))
# Out:
# 120 100 120

# %%
df=pd.DataFrame({'Brand':brands,'Price':prices})
df
# Out:
#          Brand   Price
# 0       BRUTON    ₹551
# 1       Aeonik    ₹438
# 2     RED TAPE  ₹1,059
# 3     RED TAPE  ₹1,119
# 4    Deals4you    ₹299
# ..         ...     ...
# 115       PUMA  ₹2,199
# 116       PUMA  ₹3,149
# 117       PUMA  ₹2,399
# 118  Deals4you    ₹429
# 119       PUMA  ₹2,109
#
# [120 rows x 2 columns]

# %%
#In the webpage absence of 20 product description create the different dataframe. 
df=pd.DataFrame({'Product_Description':product_des})
df
# Out:
#                                   Product_Description
# 0      Trendy & Stylish Casual Shoes Sneakers For Men
# 1   Casual Sneaker Shoes for Men | Elegantly Round...
# 2   Casual Sneaker Shoes For Men | Stylish and Com...
# 3   Trending Stylish Casual Outdoor Shoes Sneakers...
# 4                                  Sneakers For Women
# ..                                                ...
# 95            Chroma Kick Multicolor Sneakers For Men
# 96                    ST Runner v3 L Sneakers For Men
# 97                    PL SPEEDFUSION Sneakers For Men
# 98                                 Sneakers For Women
# 99                        Carina L Sneakers For Women
#
# [100 rows x 1 columns]

# %%
#display top 100 brands with price
df.head(100)
# Out:
#                     Brand   Price
# 0                  BRUTON    ₹551
# 1                  Aeonik    ₹438
# 2                RED TAPE  ₹1,059
# 3                RED TAPE  ₹1,119
# 4               Deals4you    ₹299
# ..                    ...     ...
# 95                 MEGPAR    ₹379
# 96                   PUMA  ₹3,439
# 97                   ATOM  ₹1,079
# 98                  Abros    ₹799
# 99  HRX by Hrithik Roshan  ₹1,047
#
# [100 rows x 2 columns]

# %%
#Q.6
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.azquotes.com/')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
search.click()

# %%
quote=[]
author=[]
type_of_author=[]

# %%
start=0
end=10
for page in range(start,end):
    qt=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in qt:
        quote.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]')
    next_button.click()
    time.sleep(3)

# %%
start=0
end=10
for page in range(start,end):
    at=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in at:
        author.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]')
    next_button.click()
    time.sleep(3)

# %%
start=0
end=10
for page in range(start,end):
    toq=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in toq:
        type_of_author.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]')
    next_button.click()
    time.sleep(3)

# %%
print(len(quote),len(author),len(type_of_author))
# Out:
# 1000 1000 1000

# %%
df=pd.DataFrame({'Quote':quote,'Author':author,'Type_of_Quote':type_of_author})
df
# Out:
#                                                  Quote              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                 Type_of_Quote
# ...

# %%
#

# %%
#

# %%
#Q.7
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1')

# %%
name=[]
born_dead=[]
office=[]
remark=[]

# %%
name_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div[1]/table/tbody/tr[2]/td[2]/div/strong/a')
for i in name_tags:
    nm=i.text
    name.append(nm)
    
bd_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div[1]/table/tbody/tr[2]/td[3]/div')
for i in bd_tags:
    bdd=i.text
    born_dead.append(bdd)    
    
off_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div[1]/table/tbody/tr[2]/td[4]/div[1]/span')
for i in off_tags:
    offi=i.text
    office.append(offi)

rm_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div[1]/table/tbody/tr[2]/td[5]/div')
for i in rm_tags:
    rem=i.text
    remark.append(rem)

# %%
print(len(name),len(born_dead),len(office),len(remark))
# Out:
# 0 0 0 0

# %%
#table=driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[4]/div[7]/div[1]')



#rows=1+len(driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[4]/div[6]/div/table/tbody/tr[1]'))

# %%
#cols=len(driver.find_elements(By.XPATH,'/html/body/div[1]/main/div[1]/div[1]/article/div[4]/div[6]/div'))

# %%
#for r in range(4,rows+1):
    #for p in range(1,cols+1):

# %%
#

# %%
#Q.8
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.motor1.com/')

# %%
designation=driver.find_element(By.XPATH,"/html/body/div[9]/div[2]/div/div/div[3]/div/div/div/form/input")
designation.send_keys('50 most expensive cars')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[9]/div[2]/div/div/div[3]/div/div/div/form/button[1]")
search.click()

# %%
name=[]
price=[]

# %%
name_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in name_tags:
    nm=i.text
    name.append(nm)
    
price_tags=driver.find_elements(By.XPATH,'//strong["strong"]')
for i in price_tags:
    prc=i.text
    price.append(prc)

# %%
print(len(name),len(price))
# Out:
# 51 50

# %%
df=pd.DataFrame({'Car Name':name})
df
# Out:
#                                      Car Name
# 0                           McLaren Senna GTR
# 1                                 Czinger 21C
# 2                               Ferrari Monza
# 3                          Gordon Murray T.33
# 4                           Koenigsegg Gemera
# 5                          Hennessey Venom F5
# 6                             Bentley Bacalar
# 7               Hispano Suiza Carmen Boulogne
# 8                      Bentley Mulliner Batur
# 9                                 SSC Tuatara
# 10                                Lotus Evija
# 11                        Aston Martin Vulcan
# 12                                 Delage D12
# 13                        Ferrari Daytona SP3
# 14                          McLaren Speedtail
# 15                               Rimac Nevera
# 16                              Pagani Utopia
# 17                       Pininfarina Battista
# 18                         Gordon Murray T.50
# ...

# %%
df=pd.DataFrame({'Price':price})
df
# Out:
#                           Price
# 0                  $1.7 Million
# 1           Price: $1.7 Million
# 2           Price: $1.7 Million
# 3           Price: $1.7 Million
# 4           Price: $1.7 Million
# 5           Price: $1.8 Million
# 6           Price: $1.9 Million
# 7           Price: $1.9 Million
# 8           Price: $2.0 Million
# 9           Price: $2.0 Million
# 10          Price: $2.1 Million
# 11          Price: $2.3 Million
# 12          Price: $2.3 Million
# 13          Price: $2.3 Million
# 14          Price: $2.3 Million
# 15          Price: $2.4 Million
# 16          Price: $2.5 Million
# 17          Price: $2.5 Million
# 18          Price: $2.6 Million
# 19          Price: $2.6 Million
# 20                 $2.7 Million
# 21          Price: $2.7 Million
# 22          Price: $2.8 Million
# 23          Price: $3.0 Million
# 24                 $3.0 Million
# 25          Price: $3.0 Million
# 26                 $3.1 Million
# 27          Price: $3.2 Million
# ...

# %%
#Q.5
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
designation=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
designation.send_keys('Laptop')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
#Here, set CPU type filter to "intel core i7"
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[20]/span/span[9]/li")
search.click()

# %%
title=[]
ratings=[]
price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]')
for i in title_tags:
    tit=i.text
    title.append(tit)
    
rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]')
for i in rating_tags:
    rat=i.text
    ratings.append(rat)    
    
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price"]/span/span[2]')
for i in price_tags:
    prc=i.text
    price.append(prc)

# %%
print(len(title),len(ratings),len(price))
# Out:
# 24 23 23

# %%
#Here, missing the 1 rating and price of laptop.

df=pd.DataFrame({'Title':title})
df.head(10)
# Out:
#                                                Title
# 0  Acer Aspire Lite 12th Gen Intel Core i7-1255U ...
# 1  Lenovo IdeaPad Slim 3 Intel Core i7 12th Gen 1...
# 2  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...
# 3  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...
# 4  ASUS [Smartchoice] Vivobook 15, Intel Core i7-...
# 5  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...
# 6  Dell Latitude 7480 14in FHD Laptop PC - Intel ...
# 7  Acer Travelmate Business Laptop Intel Core i7-...
# 8  Samsung Galaxy Book3 Core i7 13th Gen 1355U - ...
# 9  Dell Inspiron 7420 2in1 Laptop, Intel Core i7-...

# %%
df=pd.DataFrame({'Rating':ratings,'Price':price})
df.head(10)
# Out:
#   Rating   Price
# 0    403  52,999
# 1    505  62,933
# 2    120  49,800
# 3    705  78,990
# 4    259  61,990
# 5     62  62,990
# 6    668  47,990
# 7     38  69,688
# 8    113  77,490
# 9     77  86,190

# %%
#Q.1
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#here set location filter
search=driver.find_element(By.XPATH,"/html/body/div/div/main/div[1]/div[1]/div/div/div[2]/div[4]/div[2]/div[3]/label")
search.click()

# %%
#here set salary filter
search=driver.find_element(By.XPATH,"/html/body/div/div/main/div[1]/div[1]/div/div/div[2]/div[5]/div[2]/div[2]/label")
search.click()

# %%
job_title=[]
job_loc=[]
company_name=[]
exp_req=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="cust-job-tuple layout-wrapper lay-2 sjw__tuple "]/div/a[1]')
for i in title_tags:
    tit=i.text
    job_title.append(tit)
    
job_tags=driver.find_elements(By.XPATH,'//span[@class="locWdth"]')
for i in job_tags:
    job=i.text
    job_loc.append(job)    
    
name_tags=driver.find_elements(By.XPATH,'//div[@class=" row2"]/span/a[1]')
for i in name_tags:
    name=i.text
    company_name.append(name) 
    
exp_tags=driver.find_elements(By.XPATH,'//span[@class="expwdth"]')
for i in exp_tags:
    exp=i.text
    exp_req.append(exp)

# %%
print(len(job_title),len(job_loc),len(company_name),len(exp_req))
# Out:
# 20 20 20 20

# %%
df2=pd.DataFrame({'Job Title':job_title,'Job_Location':job_loc,'Company Name':company_name,'Experience':exp_req})
df2
# Out:
#                                          Job Title  \
# 0               GCP Data Architecture and Modeling
# 1                                   Data Scientist
# 2                         Associate Data Scientist
# 3                                   Data Scientist
# 4                            Python Data Scientist
# 5                                   Data Scientist
# 6                                   Data Scientist
# 7                              Lead Data Scientist
# 8                                   Data Scientist
# 9                     Data Scientist (Credit Risk)
# 10                        Associate Data Scientist
# 11  Senior Data Scientist - Automation and Digital
# 12                           Senior Data Scientist
# 13                               Sr Data Scientist
# 14                                  Data Scientist
# 15                                  Data Scientist
# 16                                  Data Scientist
# ...

# %%
df2.head(10)
# Out:
#                             Job Title  \
# 0  GCP Data Architecture and Modeling
# 1                      Data Scientist
# 2            Associate Data Scientist
# 3                      Data Scientist
# 4               Python Data Scientist
# 5                      Data Scientist
# 6                      Data Scientist
# 7                 Lead Data Scientist
# 8                      Data Scientist
# 9        Data Scientist (Credit Risk)
#
#                                         Job_Location  \
# 0                             Noida, Hyderabad, Pune
# 1  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 2                                              Noida
# 3                                              Noida
# 4  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 5  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 6  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 7  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# 8  Kolkata, Mumbai, New Delhi, Hyderabad, Pune, C...
# ...

# %%
#Q.2
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"input")
designation.send_keys('Data Analyst')

# %%
search=driver.find_element(By.CLASS_NAME,"iconH-zoom-white")
search.click()

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
exp_req=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//strong[@class="jobCard_pReplaceH2__xWmHg"]')
for i in title_tags:
    tit=i.text
    job_title.append(tit)
    
job_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in job_tags:
    job=i.text
    job_location.append(job)    
    
name_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in name_tags:
    name=i.text
    company_name.append(name) 
    
exp_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in exp_tags:
    exp=i.text
    exp_req.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(exp_req))
# Out:
# 20 20 20 20

# %%
df=pd.DataFrame({'Job_Title':job_title,'Job_Location':job_location,'Company_Name':company_name,'Experience':exp_req})
df
# Out:
#                                             Job_Title    Job_Location  \
# 0   Data Analyst , Senior Data Analyst , Data Anal...   Bangalore\n+8
# 1                                        Data Analyst       Bangalore
# 2                                        Data Analyst       Bangalore
# 3                                        Data Analyst  Bangalore\n+18
# 4                                   Lead Data Analyst   Bangalore\n+8
# 5                               Clinical Data Analyst   Bangalore\n+6
# 6                                        Data Analyst       Bangalore
# 7                                   Lead Data Analyst   Bangalore\n+7
# 8                               Clinical Data Analyst   Bangalore\n+6
# 9                               Clinical Data Analyst   Bangalore\n+6
# 10                                       Data Analyst       Bangalore
# 11                                       Data Analyst       Bangalore
# ...

# %%
df.head(10)
# Out:
#                                            Job_Title    Job_Location  \
# 0  Data Analyst , Senior Data Analyst , Data Anal...   Bangalore\n+8
# 1                                       Data Analyst       Bangalore
# 2                                       Data Analyst       Bangalore
# 3                                       Data Analyst  Bangalore\n+18
# 4                                  Lead Data Analyst   Bangalore\n+8
# 5                              Clinical Data Analyst   Bangalore\n+6
# 6                                       Data Analyst       Bangalore
# 7                                  Lead Data Analyst   Bangalore\n+7
# 8                              Clinical Data Analyst   Bangalore\n+6
# 9                              Clinical Data Analyst   Bangalore\n+6
#
#                              Company_Name   Experience
# 0                       appsoft solutions   0 to 4 Yrs
# 1  phoenix global re settlement servic...   3 to 8 Yrs
# ...
